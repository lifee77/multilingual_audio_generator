# %% [markdown]
# # Fine-Tuning Parler TTS with Your Nepali Voice
#
# To fine-tune the Parler TTS model with your voice, you'll need to:
# 1. Record your voice samples
# 2. Prepare a dataset
# 3. Fine-tune the model
#
# Here's a complete pipeline:

# %%
## Step 1: Install Dependencies

# Install required packages
# !pip install git+https://github.com/huggingface/parler-tts.git
# !pip install soundfile pandas tqdm matplotlib librosa
# !pip install gradio # for recording interface
# Out:
# WARNING: Ignoring invalid distribution ~ransformers (/Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages)
# Collecting git+https://github.com/huggingface/parler-tts.git
#   Cloning https://github.com/huggingface/parler-tts.git to /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/pip-req-build-zeftw7uz
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/parler-tts.git /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/pip-req-build-zeftw7uz
#   Resolved https://github.com/huggingface/parler-tts.git to commit d108732cd57788ec86bc857d99a6cabd66663d68
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting descript-audiotools@ git+https://github.com/descriptinc/audiotools (from parler_tts==0.2.2)
#   Cloning https://github.com/descriptinc/audiotools to /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/pip-install-bwv9b5sf/descript-audiotools_5fc7e36798f04e8b8b32d27ed9fcf0d1
#   Running command git clone --filter=blob:none --quiet https://github.com/descriptinc/audiotools /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/pip-install-bwv9b5sf/descript-audiotools_5fc7e36798f04e8b8b32d27ed9fcf0d1
#   Resolved https://github.com/descriptinc/audiotools to commit 348ebf2034ce24e2a91a553e3171cb00c0c71678
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<=4.46.1,>=4.46.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from parler_tts==0.2.2) (4.46.1)
# Requirement already satisfied: torch in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from parler_tts==0.2.2) (2.6.0)
# Requirement already satisfied: sentencepiece in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from parler_tts==0.2.2) (0.2.0)
# Requirement already satisfied: descript-audio-codec in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from parler_tts==0.2.2) (1.0.0)
# Requirement already satisfied: protobuf>=4.0.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from parler_tts==0.2.2) (4.25.6)
# Requirement already satisfied: filelock in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2024.11.6)
# Requirement already satisfied: requests in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (0.5.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (4.67.1)
# Requirement already satisfied: argbind>=0.3.7 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audio-codec->parler_tts==0.2.2) (0.3.9)
# Requirement already satisfied: einops in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audio-codec->parler_tts==0.2.2) (0.8.1)
# Requirement already satisfied: torchaudio in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audio-codec->parler_tts==0.2.2) (2.6.0)
# Requirement already satisfied: soundfile in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.13.1)
# Requirement already satisfied: pyloudnorm in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.1.1)
# Requirement already satisfied: importlib-resources in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (6.5.2)
# Requirement already satisfied: scipy in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.15.2)
# Requirement already satisfied: julius in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.7)
# Requirement already satisfied: ffmpy in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.5.0)
# Requirement already satisfied: ipython in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (9.0.2)
# Requirement already satisfied: rich in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (13.9.4)
# Requirement already satisfied: matplotlib in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.10.1)
# Requirement already satisfied: librosa in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.11.0)
# Requirement already satisfied: pystoi in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.4.1)
# Requirement already satisfied: torch_stoi in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.3)
# Requirement already satisfied: flatten-dict in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.4.2)
# Requirement already satisfied: markdown2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.5.3)
# Requirement already satisfied: randomname in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.1)
# Requirement already satisfied: tensorboard in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.19.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from torch->parler_tts==0.2.2) (4.12.2)
# Requirement already satisfied: networkx in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from torch->parler_tts==0.2.2) (2.8.8)
# Requirement already satisfied: jinja2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from torch->parler_tts==0.2.2) (3.1.6)
# Requirement already satisfied: fsspec in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from torch->parler_tts==0.2.2) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from torch->parler_tts==0.2.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from sympy==1.13.1->torch->parler_tts==0.2.2) (1.3.0)
# Requirement already satisfied: docstring-parser in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from argbind>=0.3.7->descript-audio-codec->parler_tts==0.2.2) (0.16)
# Requirement already satisfied: six<2.0,>=1.12 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from flatten-dict->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.17.0)
# Requirement already satisfied: decorator in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.19.1)
# Requirement already satisfied: stack_data in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from jinja2->torch->parler_tts==0.2.2) (3.0.2)
# Requirement already satisfied: audioread>=2.1.9 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.61.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.4.2)
# Requirement already satisfied: pooch>=1.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from soundfile->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.9.0.post0)
# Requirement already satisfied: future>=0.16.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pyloudnorm->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.0.0)
# Requirement already satisfied: fire in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from randomname->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from rich->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.0.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (75.6.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.1.3)
# Requirement already satisfied: pycparser in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from cffi>=1.0->soundfile->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from jedi>=0.16->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.1.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from numba>=0.51.0->librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.44.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pexpect>4.3->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pooch>=1.1->librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.3.7)
# Requirement already satisfied: wcwidth in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.13)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from scikit-learn>=1.1.0->librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.6.0)
# Requirement already satisfied: termcolor in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from fire->randomname->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.5.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from stack_data->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from stack_data->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from stack_data->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.3)
# WARNING: Ignoring invalid distribution ~ransformers (/Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# WARNING: Ignoring invalid distribution ~ransformers (/Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages)
# Requirement already satisfied: soundfile in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (0.13.1)
# Requirement already satisfied: pandas in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: tqdm in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (4.67.1)
# Requirement already satisfied: matplotlib in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (3.10.1)
# Requirement already satisfied: librosa in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (0.11.0)
# Requirement already satisfied: cffi>=1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from soundfile) (1.17.1)
# Requirement already satisfied: numpy in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from soundfile) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (0.61.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: pycparser in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pooch>=1.1->librosa) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: six>=1.5 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.1.31)
# WARNING: Ignoring invalid distribution ~ransformers (/Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# WARNING: Ignoring invalid distribution ~ransformers (/Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages)
# Requirement already satisfied: gradio in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (5.23.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.115.12)
# Requirement already satisfied: ffmpy in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.8.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (1.8.0)
# Requirement already satisfied: groovy~=0.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.29.3)
# Requirement already satisfied: jinja2<4.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (3.10.16)
# Requirement already satisfied: packaging in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (2.10.6)
# Requirement already satisfied: pydub in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.11.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.46.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.15.2)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio-client==1.8.0->gradio) (2024.12.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from gradio-client==1.8.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from pydantic>=2.0->gradio) (2.27.2)
# Requirement already satisfied: click>=8.0.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.3.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# WARNING: Ignoring invalid distribution ~ransformers (/Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/Users/jeevanbhatta/Downloads/voice-classification/venv/lib/python3.11/site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
## Step 2: Create Recording Interface
# Out:
# Loaded 1483 sentences from file

# %%
# Create Gradio interface

import os
import gradio as gr
import pandas as pd
import shutil
import traceback

# Create directories with proper permissions
os.makedirs("voice_data", exist_ok=True)

# Load Nepali sentences from text file
def load_sentences_from_file(file_path="nepali_sentences.txt"):
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            sentences = [line.strip() for line in f if line.strip()]
        if not sentences:
            raise ValueError("No sentences found in the file")
        return sentences
    except (FileNotFoundError, ValueError) as e:
        print(f"Warning: {e}. Using default sentences.")
        return [
            "नमस्ते, मेरो नाम जीवन हो।",
            "म नेपाली भाषामा बोल्छु।"
        ]

# Load sentences from file
nepali_sentences = load_sentences_from_file()
print(f"Loaded {len(nepali_sentences)} sentences from file")

# Track current recording index
current_idx = 0

def record_sample(audio_path, text):
    global current_idx
    
    if audio_path is None:
        return "Please record audio first.", current_idx, nepali_sentences[current_idx % len(nepali_sentences)]
    
    try:
        # Debug information
        print(f"Received audio path: {audio_path}")
        if not os.path.exists(audio_path):
            return f"Error: Audio file {audio_path} doesn't exist", current_idx, nepali_sentences[current_idx % len(nepali_sentences)]
        
        # Create output directory if it doesn't exist
        os.makedirs("voice_data", exist_ok=True)
        
        # Save the audio file
        output_filename = f"voice_data/sample_{current_idx:03d}.wav"
        shutil.copy(audio_path, output_filename)
        print(f"Copied audio to {output_filename}")
        
        # Save the text
        with open(f"voice_data/sample_{current_idx:03d}.txt", "w", encoding="utf-8") as f:
            f.write(text)
        
        # Update metadata
        metadata_file = "voice_data/metadata.csv"
        new_row = {"file": f"sample_{current_idx:03d}.wav", "text": text}
        
        if os.path.exists(metadata_file):
            metadata = pd.read_csv(metadata_file)
            metadata = pd.concat([metadata, pd.DataFrame([new_row])], ignore_index=True)
        else:
            metadata = pd.DataFrame([new_row])
        
        metadata.to_csv(metadata_file, index=False)
        
        # Increment index
        current_idx += 1
        
        return f"✅ Saved sample {current_idx-1}", current_idx, nepali_sentences[current_idx % len(nepali_sentences)]
    except Exception as e:
        error_details = traceback.format_exc()
        print(f"ERROR: {error_details}")
        return f"❌ Error saving recording: {str(e)}", current_idx, nepali_sentences[current_idx % len(nepali_sentences)]

# Create improved Gradio interface
with gr.Blocks() as demo:
    gr.Markdown("# Record Your Nepali Voice Samples")
    gr.Markdown("Read the sentence below and record your voice. Try to speak clearly and naturally.")
    
    with gr.Row():
        with gr.Column(scale=3):
            text_to_read = gr.Textbox(
                value=nepali_sentences[0], 
                label="Sentence to Read",
                lines=3
            )
            
            # Add both microphone recording and file upload options
            with gr.Tabs():
                with gr.TabItem("Record (Microphone)"):
                    audio_recorder = gr.Audio(
                        sources=["microphone"], 
                        type="filepath",
                        label="Record Your Voice"
                    )
                with gr.TabItem("Upload Audio"):
                    audio_upload = gr.Audio(
                        type="filepath",
                        label="Upload Audio File"
                    )
            
            record_btn = gr.Button("Save Recording", variant="primary")
            status = gr.Textbox(value="Ready to record", label="Status")
            count = gr.Number(value=0, label="Samples Recorded")
            
            # Show microphone debugging info
            debug_info = gr.HTML("""
            <details>
                <summary>Microphone Troubleshooting</summary>
                <div id='mic-debug'>
                    <p>If microphone is not working:</p>
                    <ol>
                        <li>Check browser permissions</li>
                        <li>Try refreshing the page</li>
                        <li>Try using the Upload tab instead</li>
                    </ol>
                </div>
            </details>
            """)
        
        with gr.Column(scale=2):
            gr.Markdown("""
            ### Recording Tips:
            1. Use a quiet environment
            2. Speak clearly at a consistent pace
            3. Position yourself about 20cm from the microphone
            4. Maintain consistent tone and volume
            5. Record at least 50 samples for good results
            
            ### Progress:
            - Use the number counter to track your progress
            - Aim for 50-100 recordings for best results
            """)
    
    # Connect both recording and upload
    def handle_audio(audio, text):
        if audio is not None:
            return record_sample(audio, text)
        else:
            return "No audio detected", current_idx, nepali_sentences[current_idx % len(nepali_sentences)]
    
    record_btn.click(
        handle_audio, 
        inputs=[audio_recorder, text_to_read], 
        outputs=[status, count, text_to_read]
    ).then(
        lambda: None,  # Reset audio recorder
        None,
        [audio_recorder]
    )
    
    # Also connect the upload tab
    audio_upload.change(
        handle_audio,
        inputs=[audio_upload, text_to_read],
        outputs=[status, count, text_to_read]
    )

# Launch with share=True for easier testing
demo.launch(share=True)
# Out:
# Loaded 1483 sentences from file
# * Running on local URL:  http://127.0.0.1:7867
# * Running on public URL: https://5331edc9940d31a1b9.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5331edc9940d31a1b9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/90fbbb12d4a5a88575b97dd74d25aad25f2265e9170bc63a4cfb3b3ab43b2008/audio.wav
# Copied audio to voice_data/sample_000.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/e5ef0fc122c66d42c428c778b77016217ce0b18e17018120128fa13690465cd2/audio.wav
# Copied audio to voice_data/sample_001.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/984ffd29b4a85358276146e2bf1c872c75b2b4830bb9f01b2c4d32c1c9d1d4a8/audio.wav
# Copied audio to voice_data/sample_002.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/f8d44c2bb91a52702c6a71f6f894d11081a405542d563625e85dbdd66f6ad380/audio.wav
# Copied audio to voice_data/sample_003.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/a27ee060612d7e82fb03c6de7f4b6521c57d35f37c6f26d5f42b490603ac4309/audio.wav
# Copied audio to voice_data/sample_004.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/1fe4698fd9dcdc91256e230a65c8ba7bdb499dae9ae43cfb85a71a0421060289/audio.wav
# Copied audio to voice_data/sample_005.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/0064164384ae38b6375cdbb8432e4e8933668396a38e160689e25d6c14b5a0a1/audio.wav
# Copied audio to voice_data/sample_006.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/f8d817c42232ce5448749537677a9f70976cb4a8f7ea67789e2136b2c47f3996/audio.wav
# Copied audio to voice_data/sample_007.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/f32ccb1ffb51fbbcebd3bce0c0c15194ab854bc636e4cbb1a1e546cfca5b93fe/audio.wav
# Copied audio to voice_data/sample_008.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/7ca9ca28dd3694ebe41476675e384704832cfd54af3ff68b527a3c0c1587dd52/audio.wav
# Copied audio to voice_data/sample_009.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/0841fa4ef1fc5603be5cfbd9b32ec2db9ca29e6bfb3e1206e6a871e6c32357a2/audio.wav
# Copied audio to voice_data/sample_010.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/423778322e221bbe2dd4a44ccb1966a5e352aecab6429111678317d10a2babf4/audio.wav
# Copied audio to voice_data/sample_011.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio/7e8748e314c34ada7d1451ea5e1e62326e4c3ae2f4d273cdbe977295c6b34407/audio.wav
# Copied audio to voice_data/sample_012.wav
# Received audio path: /private/var/folders/cd/vmj840453cz603ygrc6my4300000gn/T/gradio